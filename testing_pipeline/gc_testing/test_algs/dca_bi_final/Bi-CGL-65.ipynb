# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/My Drive/pr2/dca_bi_final')
#sys.path.append('/content/drive/My Drive/pr2/dca_bi_final/data')
#sys.path.append('/content/drive/My Drive/pr2/dca_bi_final/data/syntheticA')

sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/My Drive/pr2/dca_bi_final']

# %%
#!ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !ls -l /usr/bin/nvidia-smi
# Out:
# -rwxr-xr-x 1 root root 628280 Jun 28 10:11 /usr/bin/nvidia-smi

# %%
# !python /content/drive/My\ Drive/pr2/dca_bi_final/main.py --cuda=True --epochs=200
#!python /content/drive/My\ Drive/pr2/dca_bi_final/main.py
# Out:
# /content/drive/My Drive/pr2/dca_bi_final/data/syntheticA/filter_norm_expression0.mat
# Namespace(GTu_path='/content/drive/My Drive/pr2/dca_bi_final/data/syntheticA/groundtruth.mat', L1Loss=False, batch_size=64, clip=1.0, compress_p_list=[80], cuda='True', data='/content/drive/My Drive/pr2/dca_bi_final/data/syntheticA/filter_norm_expression0.mat', dropout=0.1, epochs=200, gpu=0, graph_path='/content/drive/My Drive/pr2/dca_bi_final/data/syntheticA/groundtruth.mat', horizon=1, lambda1=0.1, lowrank=50, lr=0.01, lr_decay=0.99, model='DCM_DeepCausal', normalize=1, optim='adam', p_list=[40, 40, 40, 40, 40], p_list_layer=5, p_list_number=40, pre_win=3, save='/content/drive/My Drive/pr2/dca_bi_final/data/save/model65.pt', save_gt='/content/drive/My Drive/pr2/dca_bi_final/data/save/model65_gc_gt.csv', save_out='/content/drive/My Drive/pr2/dca_bi_final/data/save/model65_gc_est.csv', seed=12345, start_decay_at=100, train=0.9, valid=0.09, weight_decay=0, window=5, y_dim=65)
# a
# b
# d
# ...
